# %% [markdown]
# # Paddy Yield Prediction — Data Analysis & Training
#
# This notebook performs data cleaning, exploratory data analysis (EDA), feature preprocessing,
# model selection/tuning, training, evaluation, and saves the trained artifacts used by the backend.
#
# Run cells in order. If plotting libraries are not installed, plots will be skipped but training will run.

# %%
# Imports
import os
from pathlib import Path
import pandas as pd
import numpy as np
import joblib

# ML libraries
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, accuracy_score

# Optional plotting libs (not required to run training)
try:
    import matplotlib.pyplot as plt
    import seaborn as sns
    PLOTTING_AVAILABLE = True
except Exception:
,
,
,
,
,
,
,
,
,
,
,
,
: 
,
: { 
: 
 },
: [
,
,
,
,
,
: 
,
: { 
: 
 },
: [
,
,
    'PredictedYield_kg_ha', 'PloughDepth_cm', 'SoilAdjustment_kgLime', 'SeedAmount_kg',
    'Fertilizer_Basal_MOP_kg', 'Fertilizer_2ndDose_Urea_kg', 'Fertilizer_2ndDose_TSP_kg',
,
    'PloughMethod', 'IrrigationAdvice', 'WaterManagementAdvice_Stage4', 'TillerIncreaseTip',
,
,
,
,
: 
,
: { 
: 
 },
: [
,
,
,
,
,
